# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Conv2D

import numpy as np
from glob import glob

# %%
batch = 32
img_height = 180
img_width = 180

train_path = r'C:\Users\Chandini\Downloads\archive (3)\Train'
test_path = r'C:\Users\Chandini\Downloads\archive (3)\Test'

# %%
import PIL, pathlib
train_path = pathlib.Path(train_path)
onehundred = list(train_path.glob('1Hundrednote/*'))
PIL.Image.open(str(onehundred[5]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=331x152 at 0x1D3F6AE6970>

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
                train_path,
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch)
# Out:
# Found 153 files belonging to 7 classes.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
  test_path,
#  validation_split=0.1,
 # subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch)
# Out:
# Found 42 files belonging to 7 classes.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['1Hundrednote', '2Hundrednote', '2Thousandnote', '5Hundrednote', 'Fiftynote', 'Tennote', 'Twentynote']

# %%
#Data Visualization

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
#normalize data by using a rescaling layer

normalization_layer = layers.experimental.preprocessing.Rescaling(1./255)

normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0072503127 1.0

# %%
Classifier=Sequential()

Classifier.add(layers.experimental.preprocessing.Rescaling(1./255,
      input_shape=(img_height, img_width, 3)))

Classifier.add(Conv2D(32,(3,3),
                      input_shape=(img_height,img_width,3), 
                      activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Conv2D(32,(3,3),activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Flatten())

Classifier.add(Dense(units = 128, activation = 'relu'))
Classifier.add(Dense(units = 7, activation = 'softmax'))

# %%
Classifier.compile(
  loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
  optimizer='adam',
  metrics=['accuracy']
)

# %%
Classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 59168)             0
#
#  dense (Dense)               (None, 128)               7573632
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 7,584,679
# Trainable params: 7,584,679
# Non-trainable params: 0
# _________________________________________________________________

# %%
from PIL import _imaging
from PIL import Image
#fit the classifier
epochs = 30
r = Classifier.fit(
  train_ds,
  validation_data=test_ds,
  epochs=epochs,
)
# Out:
# Epoch 1/30
# C:\Users\Chandini\anaconda3\lib\site-packages\tensorflow\python\util\dispatch.py:1082: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 5/5 [==============================] - 4s 801ms/step - loss: 5.7466 - accuracy: 0.1438 - val_loss: 2.5383 - val_accuracy: 0.2143
# Epoch 2/30
# 5/5 [==============================] - 3s 675ms/step - loss: 2.0875 - accuracy: 0.1895 - val_loss: 1.9454 - val_accuracy: 0.2619
# Epoch 3/30
# 5/5 [==============================] - 3s 607ms/step - loss: 1.8427 - accuracy: 0.3203 - val_loss: 1.9568 - val_accuracy: 0.2143
# Epoch 4/30
# 5/5 [==============================] - 3s 592ms/step - loss: 1.7031 - accuracy: 0.4379 - val_loss: 1.7724 - val_accuracy: 0.2857
# Epoch 5/30
# 5/5 [==============================] - 3s 578ms/step - loss: 1.4741 - accuracy: 0.5556 - val_loss: 1.5980 - val_accuracy: 0.4524
# Epoch 6/30
# 5/5 [==============================] - 3s 584ms/step - loss: 1.1252 - accuracy: 0.6797 - val_loss: 1.3468 - val_accuracy: 0.5000
# Epoch 7/30
# 5/5 [==============================] - 3s 553ms/step - loss: 0.8206 - accuracy: 0.8105 - val_loss: 1.2134 - val_accuracy: 0.6190
# Epoch 8/30
# 5/5 [==============================] - 3s 530ms/step - loss: 0.5587 - accuracy: 0.9020 - val_loss: 1.2934 - val_accuracy: 0.5238
# Epoch 9/30
# 5/5 [==============================] - 3s 555ms/step - loss: 0.3760 - accuracy: 0.8889 - val_loss: 1.1738 - val_accuracy: 0.5714
# Epoch 10/30
# 5/5 [==============================] - 3s 627ms/step - loss: 0.1905 - accuracy: 0.9804 - val_loss: 1.0997 - val_accuracy: 0.6905
# Epoch 11/30
# 5/5 [==============================] - 3s 549ms/step - loss: 0.1143 - accuracy: 0.9869 - val_loss: 1.0316 - val_accuracy: 0.6429
# Epoch 12/30
# 5/5 [==============================] - 3s 642ms/step - loss: 0.0603 - accuracy: 0.9935 - val_loss: 1.1583 - val_accuracy: 0.5714
# Epoch 13/30
# 5/5 [==============================] - 3s 638ms/step - loss: 0.0288 - accuracy: 1.0000 - val_loss: 1.3052 - val_accuracy: 0.5714
# Epoch 14/30
# 5/5 [==============================] - 3s 653ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 1.1179 - val_accuracy: 0.5714
# Epoch 15/30
# 5/5 [==============================] - 3s 583ms/step - loss: 0.0132 - accuracy: 1.0000 - val_loss: 1.1657 - val_accuracy: 0.5714
# Epoch 16/30
# 5/5 [==============================] - 3s 710ms/step - loss: 0.0084 - accuracy: 1.0000 - val_loss: 1.2198 - val_accuracy: 0.6667
# Epoch 17/30
# 5/5 [==============================] - 3s 540ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 1.2854 - val_accuracy: 0.6429
# Epoch 18/30
# 5/5 [==============================] - 3s 540ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 1.2256 - val_accuracy: 0.6667
# Epoch 19/30
# 5/5 [==============================] - 3s 544ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.2246 - val_accuracy: 0.6429
# Epoch 20/30
# 5/5 [==============================] - 3s 532ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.2200 - val_accuracy: 0.6429
# Epoch 21/30
# 5/5 [==============================] - 3s 597ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.2831 - val_accuracy: 0.5714
# Epoch 22/30
# 5/5 [==============================] - 3s 571ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.2772 - val_accuracy: 0.5952
# Epoch 23/30
# 5/5 [==============================] - 3s 549ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.2375 - val_accuracy: 0.6190
# Epoch 24/30
# 5/5 [==============================] - 3s 548ms/step - loss: 9.4022e-04 - accuracy: 1.0000 - val_loss: 1.2362 - val_accuracy: 0.6190
# Epoch 25/30
# 5/5 [==============================] - 3s 559ms/step - loss: 8.1303e-04 - accuracy: 1.0000 - val_loss: 1.2789 - val_accuracy: 0.6667
# Epoch 26/30
# 5/5 [==============================] - 3s 561ms/step - loss: 7.5072e-04 - accuracy: 1.0000 - val_loss: 1.2996 - val_accuracy: 0.6667
# Epoch 27/30
# 5/5 [==============================] - 3s 586ms/step - loss: 6.8335e-04 - accuracy: 1.0000 - val_loss: 1.2742 - val_accuracy: 0.6667
# Epoch 28/30
# 5/5 [==============================] - 3s 611ms/step - loss: 6.3029e-04 - accuracy: 1.0000 - val_loss: 1.2573 - val_accuracy: 0.6667
# Epoch 29/30
# 5/5 [==============================] - 3s 577ms/step - loss: 5.8593e-04 - accuracy: 1.0000 - val_loss: 1.2613 - val_accuracy: 0.6667
# Epoch 30/30
# 5/5 [==============================] - 3s 623ms/step - loss: 5.4974e-04 - accuracy: 1.0000 - val_loss: 1.2715 - val_accuracy: 0.6429

# %%
mean_val = (sum(r.history['val_accuracy']))/(len(r.history['val_accuracy']))
print('mean_test_accuracy: ', mean_val)
# Out:
# mean_test_accuracy:  0.5634920756022136

# %%
mean_train = (sum(r.history['accuracy']))/(len(r.history['accuracy']))
print('mean_train_accuracy: ', mean_train)
# Out:
# mean_train_accuracy:  0.8629629661639532

# %%
import matplotlib.pyplot as plt
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='test accuracy')
plt.legend()
plt.show()

# %%
#Data Augmentation to reduce overfitting

data_augmentation = tf.keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %%
Classifier=Sequential()

Classifier.add(data_augmentation)
Classifier.add(layers.experimental.preprocessing.Rescaling(1./255,
      input_shape=(img_height, img_width, 3)))

Classifier.add(Conv2D(32,(3,3),
                      input_shape=(img_height,img_width,3), 
                      activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))

Classifier.add(Conv2D(32,(3,3),activation='relu'))
Classifier.add(MaxPooling2D(pool_size=(2,2)))
Classifier.add(layers.Dropout(0.2))

Classifier.add(Flatten())

Classifier.add(Dense(units = 128, activation = 'relu'))
Classifier.add(Dense(units = 7, activation = 'softmax'))

# %%
Classifier.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 33
r = Classifier.fit(
  train_ds,
  validation_data=test_ds,
  epochs=epochs
)
# Out:
# Epoch 1/33
# 5/5 [==============================] - 5s 783ms/step - loss: 7.7589 - accuracy: 0.1046 - val_loss: 3.5845 - val_accuracy: 0.1429
# Epoch 2/33
# 5/5 [==============================] - 4s 752ms/step - loss: 2.3032 - accuracy: 0.1438 - val_loss: 1.9339 - val_accuracy: 0.1667
# Epoch 3/33
# 5/5 [==============================] - 3s 639ms/step - loss: 1.9073 - accuracy: 0.2484 - val_loss: 1.9100 - val_accuracy: 0.1429
# Epoch 4/33
# 5/5 [==============================] - 4s 721ms/step - loss: 1.7847 - accuracy: 0.2222 - val_loss: 1.6306 - val_accuracy: 0.2143
# Epoch 5/33
# 5/5 [==============================] - 3s 647ms/step - loss: 1.6278 - accuracy: 0.2810 - val_loss: 1.9615 - val_accuracy: 0.2143
# Epoch 6/33
# 5/5 [==============================] - 4s 740ms/step - loss: 1.5442 - accuracy: 0.4444 - val_loss: 1.3476 - val_accuracy: 0.4286
# Epoch 7/33
# 5/5 [==============================] - 3s 638ms/step - loss: 1.2284 - accuracy: 0.5556 - val_loss: 1.3625 - val_accuracy: 0.4524
# Epoch 8/33
# 5/5 [==============================] - 4s 731ms/step - loss: 1.3000 - accuracy: 0.4837 - val_loss: 1.3260 - val_accuracy: 0.3810
# Epoch 9/33
# 5/5 [==============================] - 4s 747ms/step - loss: 1.1982 - accuracy: 0.5163 - val_loss: 1.1072 - val_accuracy: 0.4762
# Epoch 10/33
# 5/5 [==============================] - 3s 617ms/step - loss: 1.1579 - accuracy: 0.5686 - val_loss: 1.0891 - val_accuracy: 0.5714
# Epoch 11/33
# 5/5 [==============================] - 3s 718ms/step - loss: 1.0826 - accuracy: 0.5882 - val_loss: 1.0776 - val_accuracy: 0.5714
# Epoch 12/33
# 5/5 [==============================] - 3s 636ms/step - loss: 1.0051 - accuracy: 0.6275 - val_loss: 0.8585 - val_accuracy: 0.6429
# Epoch 13/33
# 5/5 [==============================] - 3s 693ms/step - loss: 0.8687 - accuracy: 0.6928 - val_loss: 0.9761 - val_accuracy: 0.5476
# Epoch 14/33
# 5/5 [==============================] - 3s 614ms/step - loss: 0.7675 - accuracy: 0.7255 - val_loss: 0.7189 - val_accuracy: 0.7143
# Epoch 15/33
# 5/5 [==============================] - 3s 683ms/step - loss: 0.6282 - accuracy: 0.7712 - val_loss: 0.7640 - val_accuracy: 0.5714
# Epoch 16/33
# 5/5 [==============================] - 3s 645ms/step - loss: 0.5300 - accuracy: 0.8235 - val_loss: 0.6772 - val_accuracy: 0.6667
# Epoch 17/33
# 5/5 [==============================] - 3s 640ms/step - loss: 0.5365 - accuracy: 0.8235 - val_loss: 0.8110 - val_accuracy: 0.6429
# Epoch 18/33
# 5/5 [==============================] - 3s 630ms/step - loss: 0.4537 - accuracy: 0.8170 - val_loss: 0.8316 - val_accuracy: 0.6905
# Epoch 19/33
# 5/5 [==============================] - 3s 588ms/step - loss: 0.4425 - accuracy: 0.8431 - val_loss: 0.5853 - val_accuracy: 0.7619
# Epoch 20/33
# 5/5 [==============================] - 4s 789ms/step - loss: 0.3426 - accuracy: 0.8954 - val_loss: 1.0020 - val_accuracy: 0.6905
# Epoch 21/33
# 5/5 [==============================] - 3s 673ms/step - loss: 0.3278 - accuracy: 0.8693 - val_loss: 0.6602 - val_accuracy: 0.7619
# Epoch 22/33
# 5/5 [==============================] - 3s 702ms/step - loss: 0.3744 - accuracy: 0.8693 - val_loss: 0.8703 - val_accuracy: 0.6667
# Epoch 23/33
# 5/5 [==============================] - 3s 699ms/step - loss: 0.3408 - accuracy: 0.8824 - val_loss: 0.8655 - val_accuracy: 0.6667
# Epoch 24/33
# 5/5 [==============================] - 3s 701ms/step - loss: 0.2864 - accuracy: 0.9020 - val_loss: 0.7183 - val_accuracy: 0.7143
# Epoch 25/33
# 5/5 [==============================] - 3s 680ms/step - loss: 0.2829 - accuracy: 0.8889 - val_loss: 1.1102 - val_accuracy: 0.6190
# Epoch 26/33
# 5/5 [==============================] - 3s 699ms/step - loss: 0.3270 - accuracy: 0.8758 - val_loss: 0.5455 - val_accuracy: 0.7619
# Epoch 27/33
# 5/5 [==============================] - 4s 706ms/step - loss: 0.2332 - accuracy: 0.9150 - val_loss: 1.0654 - val_accuracy: 0.6905
# Epoch 28/33
# 5/5 [==============================] - 4s 820ms/step - loss: 0.2505 - accuracy: 0.9020 - val_loss: 0.6721 - val_accuracy: 0.7619
# Epoch 29/33
# 5/5 [==============================] - 3s 650ms/step - loss: 0.2255 - accuracy: 0.9281 - val_loss: 0.9711 - val_accuracy: 0.6905
# Epoch 30/33
# 5/5 [==============================] - 3s 722ms/step - loss: 0.2830 - accuracy: 0.8824 - val_loss: 0.9475 - val_accuracy: 0.6905
# Epoch 31/33
# 5/5 [==============================] - 3s 660ms/step - loss: 0.2184 - accuracy: 0.9281 - val_loss: 0.6904 - val_accuracy: 0.7619
# Epoch 32/33
# 5/5 [==============================] - 3s 605ms/step - loss: 0.1975 - accuracy: 0.9346 - val_loss: 0.7310 - val_accuracy: 0.7381
# Epoch 33/33
# 5/5 [==============================] - 3s 608ms/step - loss: 0.2079 - accuracy: 0.9085 - val_loss: 0.9845 - val_accuracy: 0.7143

# %%
mean_val = (sum(r.history['val_accuracy']))/(len(r.history['val_accuracy']))
print('mean_test_accuracy: ', mean_val)
print('\n')
mean_train = (sum(r.history['accuracy']))/(len(r.history['accuracy']))
print('mean_train_accuracy: ', mean_train)
# Out:
# mean_test_accuracy:  0.5735930804953431
#
#
# mean_train_accuracy:  0.6928104674725821

# %%
import matplotlib.pyplot as plt
# plot the loss
plt.plot(r.history['loss'], label='train loss')
plt.plot(r.history['val_loss'], label='test loss')
plt.legend()
plt.show()

# plot the accuracy
plt.plot(r.history['accuracy'], label='train accuracy')
plt.plot(r.history['val_accuracy'], label='test accuracy')
plt.legend()
plt.show()

# %%
#Use classifier to run prediction on any new image

from tensorflow.keras.preprocessing import image
img = image.load_img(r"C:\Users\Chandini\Desktop\opencv practice\curr\files\test_50_3.jpg",
                       target_size=(img_height,img_width))
img
# Out:
# <PIL.Image.Image image mode=RGB size=180x180 at 0x1D396048E20>

# %%
test_image=image.img_to_array(img)
test_image=np.expand_dims(test_image, axis = 0)

result =np.argmax(Classifier.predict(test_image), axis=1)
result
# Out:
# array([4], dtype=int64)

# %%
prediction = class_names[result[0]]
prediction
# Out:
# 'Fiftynote'
